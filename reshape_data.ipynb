# %%
import cv2 as cv
import os
import pathlib
import matplotlib.pyplot as plt
from utils.image import rectangle_image

# %%
original_path = ['.', 'data', 'new_data']
new_path = ['.', 'data', 'rectangle_data']

# %%
rectangle_image(original_path=original_path,
                original_label='OK',
                x=135, y=40,
                new_size_x=135,
                new_size_y=40,
                new_path=new_path,
                label_left='OK',
                label_right='OK')

# %%
centralize(image_path=datadir, x=145, y=45, new_size=224, new_path=newdir)

# %%
img1 = os.path.join(*datadir, listfile[2])

# %%
im = plt.imread(img1)

# %%
plt.imshow(im)

# %%
x = 145
y = 40
x_start = (224 - x) // 2
y_start = (224 - 2*y) // 2
print('x_start: ', x_start)
print('y_start: ', y_start)
# Out:
# x_start:  39
# y_start:  72

# %%
new_image = np.zeros(shape=(224, 224, 3), dtype=np.int32)
new_image[x_start:x_start+x, y_start:y_start+y, :] = im[:x, :y, :]
new_image[x_start:x_start+x, y_start+y:y_start+2*y, :] = im[:x, 256-y:, :]

# %%
plt.imshow(new_image)

# %%
new_image /= 255.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-a403487bae82> in <module>
# ----> 1 new_image /= 255.
#
# TypeError: ufunc 'true_divide' output (typecode 'd') could not be coerced to provided output parameter (typecode 'l') according to the casting rule ''same_kind''

# %%
plt.imshow(new_image)

# %%
plt.imsave('abc.jpg', new_image)
